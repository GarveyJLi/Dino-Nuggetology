# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from img_pipeline import *

# %%
img1 = '../gli_images/IMG_E3919.JPG'
img2 = '../gli_images/IMG_E3920.JPG'
img3 = '../gli_images/IMG_E3923.JPG'
img4 = '../gli_images/IMG_E3924.JPG'

e1 = process_image(img1)
e2 = process_image(img2)
e3 = process_image(img3)
e4 = process_image(img4)

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

ax[0][0].imshow(e1, cmap='gray', vmin=0, vmax=255)
ax[0][1].imshow(e1, cmap='gray', vmin=0, vmax=255)
ax[1][0].imshow(e1, cmap='gray', vmin=0, vmax=255)
ax[1][1].imshow(e1, cmap='gray', vmin=0, vmax=255)
