# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from img_pipeline import *

# %%
img1 = '../edge_det_testing/test_imgs/IMG_0001.jpg'
img2 = '../edge_det_testing/test_imgs/IMG_0010.jpg'
img3 = '../edge_det_testing/test_imgs/IMG_0030.jpg'
img4 = '../edge_det_testing/test_imgs/IMG_0031.jpg'

e1 = process_image(img1)
e2 = process_image(img2)
e3 = process_image(img3)
e4 = process_image(img4)

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

ax[0][0].imshow(e1[5], cmap='gray', vmin=0, vmax=255)
ax[0][1].imshow(e2[5], cmap='gray', vmin=0, vmax=255)
ax[1][0].imshow(e3[5], cmap='gray', vmin=0, vmax=255)
ax[1][1].imshow(e4[5], cmap='gray', vmin=0, vmax=255)
